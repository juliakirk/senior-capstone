# %%
import requests
import pandas as pd

# %%
key = "4dd05398874a3f0c4f32e74f4c0fa269655cf923"

# %%
requests.get("https://api.census.gov/data/2023/acs/acs1/profile?get=NAME&for=urban%20area:*"+key)
# Out:
# <Response [400]>

# %%
urbanAreas = requests.get("https://api.census.gov/data/2023/acs/acs1/profile?get=NAME&for=urban%20area:*")

cities = urbanAreas.json()
cityDF = pd.DataFrame(cities)
cityDF.to_csv('apiCity.csv', index=False)

# %%
urban_areas_df = pd.read_csv('../datasets/capstoneData.csv', dtype={'CensusCode': str})
codes = urban_areas_df.iloc[:, 3]
codes
# Out:
# 0     02305
# 1     40780
# 2     07786
# 3     50392
# 4     69184
#       ...
# 95    83764
# 96    53200
# 97    57466
# 98    15481
# 99    16237
# Name: CensusCode, Length: 100, dtype: object

# %%
populations = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200101_001E&for=urban%20area:{i}&key={key}")
    
    if response.status_code == 200:  # Check if the request was successful
        data = response.json()
        value = data[1][1]
        populations.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        populations.append(None)

# Add the population data as a new column in the DataFrame
urban_areas_df['Population'] = populations

# Save the updated DataFrame back to a CSV file
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)

# Optionally, check the DataFrame to see the new column
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population
# 0    Anchorage    Alaska        AK      02305     245624
# 1   Huntsville   Alabama        AL      40780     359389
# 2   Birmingham   Alabama        AL      07786     778756
# 3  Little Rock  Arkansas        AR      50392     467846
# 4      Phoenix   Arizona        AZ      69184    4065338

# %%
geographicMobility = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200701_002E&for=urban%20area:{i}&key={key}")
    
    if response.status_code == 200:  # Check if the request was successful
        data = response.json()
        value = data[1][1] 
        geographicMobility.append(value)
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        geographicMobility.append(None)  # Append None if there was an error for this code

#Add the population data as a new column in the DataFrame
urban_areas_df['sameHouse1yr'] = geographicMobility

# Save the updated DataFrame back to a CSV file
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)

# Optionally, check the DataFrame to see the new column
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480

# %%
urban_areas_df
# Out:
#            City           State StateCode CensusCode Population sameHouse1yr  \
# 0     Anchorage          Alaska        AK      02305     245624       197589
# 1    Huntsville         Alabama        AL      40780     359389       301448
# 2    Birmingham         Alabama        AL      07786     778756       669858
# 3   Little Rock        Arkansas        AR      50392     467846       409973
# 4       Phoenix         Arizona        AZ      69184    4065338      3457480
# ..          ...             ...       ...        ...        ...          ...
# 95      Spokane      Washington        WA      83764     458988       386753
# 96      Madison       Wisconsin        WI      53200     460255       360680
# 97    Milwaukee       Wisconsin        WI      57466    1290221      1129593
# 98   Charleston  West Virginia         WV      15481     133045       121105
# 99     Cheyenne         Wyoming        WY      16237      81378        69092
#
# ...

# %%
car = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200801_002E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200:  # Check if the request was successful
        data = response.json()
        value = data[1][1] 
        #print(value) # Access the second list, then the second element (the population)
        car.append(value)  # Add the population to the list
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        car.append(None)  # Append None if there was an error for this code

#Add the population data as a new column in the DataFrame
urban_areas_df['transportCar'] = car

# Save the updated DataFrame back to a CSV file
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)

# Optionally, check the DataFrame to see the new column
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar
# 0        94067
# 1       139891
# 2       285726
# 3       165697
# 4      1332557

# %%
publicTransport = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200801_002E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        publicTransport.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        publicTransport.append(None)
urban_areas_df['publicTransport'] = publicTransport
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport
# 0        94067           94067
# 1       139891          139891
# 2       285726          285726
# 3       165697          165697
# 4      1332557         1332557

# %%
medianHouseholdIncome = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K201902_001E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        medianHouseholdIncome.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        medianHouseholdIncome.append(None)
urban_areas_df['medianIncome'] = medianHouseholdIncome
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome
# 0        94067           94067        90793
# 1       139891          139891        86901
# 2       285726          285726        69947
# 3       165697          165697        62478
# 4      1332557         1332557        85268

# %%
employment = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K202301_002E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        employment.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        employment.append(None)
urban_areas_df['employment'] = employment
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment
# 0        94067           94067        90793     140198
# 1       139891          139891        86901     194391
# 2       285726          285726        69947     390541
# 3       165697          165697        62478     230250
# 4      1332557         1332557        85268    2154287

# %%
rent = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K202502_003E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        rent.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        rent.append(None)
urban_areas_df['rent'] = rent
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent
# 0        94067           94067        90793     140198   37984
# 1       139891          139891        86901     194391   51035
# 2       285726          285726        69947     390541  110597
# 3       165697          165697        62478     230250   78957
# 4      1332557         1332557        85268    2154287  561892

# %%
own = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K202502_002E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        own.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        own.append(None)
urban_areas_df['own'] = own
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981

# %%
housingTenure = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K202502_001E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        housingTenure.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        housingTenure.append(None)
urban_areas_df['housingTenure'] = housingTenure
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure
# 0         94883
# 1        147660
# 2        317841
# 3        195305
# 4       1586873

# %%
medianValue = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K202510_001E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        medianValue.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        medianValue.append(None)
urban_areas_df['medianValue'] = medianValue
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue
# 0         94883      373200
# 1        147660      326700
# ...

# %%
medianRent = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K202511_001E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        medianRent.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        medianValue.append(None)
urban_areas_df['medianRent'] = medianRent
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue medianRent
# 0         94883      373200       1473
# ...

# %%
white = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200201_002E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        white.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        white.append(None)
urban_areas_df['white'] = white
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue medianRent    white
# 0         94883      373200       1473   130397
# ...

# %%
black = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200201_003E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        black.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        black.append(None)
urban_areas_df['black'] = black
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue medianRent    white   black
# ...

# %%
asian = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200201_005E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        asian.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        asian.append(None)
urban_areas_df['asian'] = asian
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue medianRent    white   black   asian
# ...

# %%
twoPlusRaces = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200201_008E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        twoPlusRaces.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        twoPlusRaces.append(None)
urban_areas_df['twoPlusRaces'] = twoPlusRaces
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue medianRent    white   black   asian twoPlusRaces
# ...

# %%
hispanic = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200301_003E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        hispanic.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        hispanic.append(None)
urban_areas_df['hispanic'] = hispanic
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment    rent      own  \
# 0        94067           94067        90793     140198   37984    56899
# 1       139891          139891        86901     194391   51035    96625
# 2       285726          285726        69947     390541  110597   207244
# 3       165697          165697        62478     230250   78957   116348
# 4      1332557         1332557        85268    2154287  561892  1024981
#
#   housingTenure medianValue medianRent    white   black   asian twoPlusRaces  \
# ...

# %%
foreignBorn = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200503_006E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        foreignBorn.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        foreignBorn.append(None)
urban_areas_df['foreignBorn'] = foreignBorn
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment  ...      own  \
# 0        94067           94067        90793     140198  ...    56899
# 1       139891          139891        86901     194391  ...    96625
# 2       285726          285726        69947     390541  ...   207244
# 3       165697          165697        62478     230250  ...   116348
# 4      1332557         1332557        85268    2154287  ...  1024981
#
#   housingTenure medianValue medianRent    white   black   asian twoPlusRaces  \
# ...

# %%
commuteless10 = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200802_002E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        commuteless10.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        commuteless10.append(None)
urban_areas_df['commuteless10'] = commuteless10
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment  ... housingTenure  \
# 0        94067           94067        90793     140198  ...         94883
# 1       139891          139891        86901     194391  ...        147660
# 2       285726          285726        69947     390541  ...        317841
# 3       165697          165697        62478     230250  ...        195305
# 4      1332557         1332557        85268    2154287  ...       1586873
#
#   medianValue medianRent    white   black   asian twoPlusRaces hispanic  \
# ...

# %%
commute10to29 = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200802_003E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        commute10to29.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        commute10to29.append(None)
urban_areas_df['commute10to29'] = commute10to29
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment  ... medianValue  \
# 0        94067           94067        90793     140198  ...      373200
# 1       139891          139891        86901     194391  ...      326700
# 2       285726          285726        69947     390541  ...      278700
# 3       165697          165697        62478     230250  ...      216200
# 4      1332557         1332557        85268    2154287  ...      467000
#
#   medianRent    white   black   asian twoPlusRaces hispanic foreignBorn  \
# ...

# %%
commute30to59 = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200802_004E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        commute30to59.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        commute30to59.append(None)
urban_areas_df['commute30to59'] = commute30to59
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment  ... medianRent  \
# 0        94067           94067        90793     140198  ...       1473
# 1       139891          139891        86901     194391  ...       1291
# 2       285726          285726        69947     390541  ...       1208
# 3       165697          165697        62478     230250  ...       1063
# 4      1332557         1332557        85268    2154287  ...       1754
#
#      white   black   asian twoPlusRaces hispanic foreignBorn commuteless10  \
# ...

# %%
commute60plus = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200802_005E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        commute60plus.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        commute60plus.append(None)
urban_areas_df['commute60plus'] = commute60plus
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment  ...    white   black  \
# 0        94067           94067        90793     140198  ...   130397   13071
# 1       139891          139891        86901     194391  ...   216895   92897
# 2       285726          285726        69947     390541  ...   400215  298319
# 3       165697          165697        62478     230250  ...   256905  143785
# 4      1332557         1332557        85268    2154287  ...  2445320  228098
#
#     asian twoPlusRaces hispanic foreignBorn commuteless10 commute10to29  \
# ...

# %%
counttraveltime = []
for i in codes:
    response = requests.get(f"https://api.census.gov/data/2023/acs/acsse?get=NAME,K200802_001E&for=urban%20area:{i}&key={key}")
    if response.status_code == 200: 
        data = response.json()
        value = data[1][1] 
        counttraveltime.append(value) 
    else:
        print(f"Error: {response.status_code} for urban area code {i}")
        counttraveltime.append(None)
urban_areas_df['counttraveltime'] = counttraveltime
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)
print(urban_areas_df.head())
# Out:
#           City     State StateCode CensusCode Population sameHouse1yr  \
# 0    Anchorage    Alaska        AK      02305     245624       197589
# 1   Huntsville   Alabama        AL      40780     359389       301448
# 2   Birmingham   Alabama        AL      07786     778756       669858
# 3  Little Rock  Arkansas        AR      50392     467846       409973
# 4      Phoenix   Arizona        AZ      69184    4065338      3457480
#
#   transportCar publicTransport medianIncome employment  ...   black   asian  \
# 0        94067           94067        90793     140198  ...   13071   26005
# 1       139891          139891        86901     194391  ...   92897   10440
# 2       285726          285726        69947     390541  ...  298319   17417
# 3       165697          165697        62478     230250  ...  143785   10477
# 4      1332557         1332557        85268    2154287  ...  228098  200435
#
#   twoPlusRaces hispanic foreignBorn commuteless10 commute10to29 commute30to59  \
# ...

# %%
urban_areas_df = urban_areas_df.drop(['congressionalDistrict'], axis=1)

# %%
urban_areas_df.to_csv('../datasets/capstoneData.csv', index=False)

# %%
urban_areas_df
# Out:
#            City           State StateCode CensusCode Population sameHouse1yr  \
# 0     Anchorage          Alaska        AK      02305     245624       197589
# 1    Huntsville         Alabama        AL      40780     359389       301448
# 2    Birmingham         Alabama        AL      07786     778756       669858
# 3   Little Rock        Arkansas        AR      50392     467846       409973
# 4       Phoenix         Arizona        AZ      69184    4065338      3457480
# ..          ...             ...       ...        ...        ...          ...
# 95      Spokane      Washington        WA      83764     458988       386753
# 96      Madison       Wisconsin        WI      53200     460255       360680
# 97    Milwaukee       Wisconsin        WI      57466    1290221      1129593
# 98   Charleston  West Virginia         WV      15481     133045       121105
# 99     Cheyenne         Wyoming        WY      16237      81378        69092
#
# ...
